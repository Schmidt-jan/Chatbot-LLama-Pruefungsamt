# %%
# %pip install --upgrade pip
# %pip install langchain
# %pip install llama-cpp-python==
# Out:
# Requirement already satisfied: pip in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (24.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.1.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.9 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (0.0.9)
# Requirement already satisfied: langchain-core<0.2,>=0.1.7 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (0.1.7)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.77 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (0.0.77)
# Requirement already satisfied: numpy<2,>=1 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (1.26.3)
# Requirement already satisfied: pydantic<3,>=1 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (2.5.3)
# Requirement already satisfied: requests<3,>=2 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.7->langchain) (4.2.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from langchain-core<0.2,>=0.1.7->langchain) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.7->langchain) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-cpp-python in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.2.27)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from llama-cpp-python) (4.9.0)
# Requirement already satisfied: numpy>=1.20.0 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from llama-cpp-python) (1.26.3)
# Requirement already satisfied: diskcache>=5.6.1 in /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from llama-cpp-python) (5.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Hier wird eine Datenbank erzeugt und gespeichert.

# %%
from llama_index import SimpleDirectoryReader
from llama_index.node_parser import SentenceSplitter
from langchain.text_splitter import RecursiveCharacterTextSplitter
from llama_index.schema import TextNode
from langchain_community.vectorstores.chroma import Chroma
from langchain_community.embeddings import LlamaCppEmbeddings
from llama_index.llms import LlamaCPP

data_path = "/home/tpllmws23/llms/main_data"
database_path = "/home/tpllmws23/Chatbot-LLama-Pruefungsamt/Chatbot-Jan/chromadb_lanchain_rag_auto_embeddings/"
database_collection = "Pruefungsamt"
model_path = "/home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf"

print("##########################")
print("### Load directory     ###")
print("##########################")
raw_documents = SimpleDirectoryReader(data_path).load_data()

print("##############################")
print("### Load llm and embedding ###")
print("##############################")

""" llm = LlamaCPP(model_path=model_path,
        context_window=4096,
        verbose=False,
        temperature=0.0,
)
 """
embedding = LlamaCppEmbeddings(model_path=model_path, n_ctx=1024)

print("#################################")
print("### Split docs into sentences ###")
print("#################################")

text_parser = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )

text_chunks = []
# maintain relationship with source doc index, to help inject doc metadata in (3)
doc_idxs = []
for doc_idx, page in enumerate(raw_documents):
    page_text = page.get_text()
    cur_text_chunks = text_parser.split_text(page_text)
    text_chunks.extend(cur_text_chunks)
    doc_idxs.extend([doc_idx] * len(cur_text_chunks))


nodes = []
for idx, text_chunk in enumerate(text_chunks):
    node = TextNode(
        text=text_chunk,
    )
    src_doc_idx = doc_idxs[idx]
    src_page = raw_documents[src_doc_idx]
    nodes.append(node)

for i, node in enumerate(nodes):
    try:
        node_embedding = embedding.embed_query(node.text)
        node.embedding = node_embedding
    except Exception as e:
        print(f"Failed to embed node {i}: {e}")

for idx, node in enumerate(nodes):
    node.metadata = raw_documents[doc_idxs[idx]].metadata


embeddings = []
documents = []
metadatas = []
ids = []

for node in nodes:
    embeddings.append(node.embedding)
    documents.append(node.text)
    metadatas.append(node.metadata)
    ids.append(node.id_)


print("##########################")
print("### Store in database  ###")
print("##########################")

import chromadb

client = chromadb.PersistentClient(path=database_path)

collection = client.get_or_create_collection(database_collection)
collection.add(ids=ids, embeddings=embeddings, documents=documents, metadatas=metadatas)
# Out:
# ##########################
# ### Load directory     ###
# ##########################
# ##############################
# ### Load llm and embedding ###
# ##############################
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: NVIDIA TITAN RTX, compute capability 7.5, VMM: yes
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V2
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: n_embd_k_gqa     = 5120
# llm_load_print_meta: n_embd_v_gqa     = 5120
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 7.33 GiB (4.83 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size       =    0.14 MiB
# llm_load_tensors: using CUDA for GPU acceleration
# llm_load_tensors: system memory used  = 7500.99 MiB
# llm_load_tensors: offloading 0 repeating layers to GPU
# llm_load_tensors: offloaded 0/41 layers to GPU
# ....................................................................................................
# llama_new_context_with_model: n_ctx      = 1024
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  =  800.00 MiB, K (f16):  400.00 MiB, V (f16):  400.00 MiB
# llama_build_graph: non-view tensors processed: 844/844
# llama_new_context_with_model: compute buffer total size = 4.94 MiB
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 1 | AVX512_VBMI = 0 | AVX512_VNNI = 1 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |
# #################################
# ### Split docs into sentences ###
# #################################
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6106.28 ms /    92 tokens (   66.37 ms per token,    15.07 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6126.50 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4129.58 ms /    63 tokens (   65.55 ms per token,    15.26 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4142.00 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2765.98 ms /    42 tokens (   65.86 ms per token,    15.18 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    2775.56 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    1260.73 ms /    19 tokens (   66.35 ms per token,    15.07 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    1265.66 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2493.82 ms /    38 tokens (   65.63 ms per token,    15.24 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    2501.56 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2957.16 ms /    46 tokens (   64.29 ms per token,    15.56 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    2966.24 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2607.46 ms /    40 tokens (   65.19 ms per token,    15.34 tokens per second)
# llama_print_timings:        eval time =     140.53 ms /     1 runs   (  140.53 ms per token,     7.12 tokens per second)
# llama_print_timings:       total time =    2757.24 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3350.70 ms /    51 tokens (   65.70 ms per token,    15.22 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3361.07 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2902.87 ms /    45 tokens (   64.51 ms per token,    15.50 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    2911.86 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3026.50 ms /    46 tokens (   65.79 ms per token,    15.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3035.82 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3582.26 ms /    56 tokens (   63.97 ms per token,    15.63 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3593.35 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3145.13 ms /    48 tokens (   65.52 ms per token,    15.26 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3154.66 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3121.66 ms /    48 tokens (   65.03 ms per token,    15.38 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3131.46 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3575.45 ms /    56 tokens (   63.85 ms per token,    15.66 tokens per second)
# llama_print_timings:        eval time =     141.04 ms /     1 runs   (  141.04 ms per token,     7.09 tokens per second)
# llama_print_timings:       total time =    3728.74 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4039.47 ms /    61 tokens (   66.22 ms per token,    15.10 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4052.21 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3060.18 ms /    47 tokens (   65.11 ms per token,    15.36 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3069.51 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2957.99 ms /    46 tokens (   64.30 ms per token,    15.55 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    2967.21 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3001.92 ms /    46 tokens (   65.26 ms per token,    15.32 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3011.18 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    1481.16 ms /    23 tokens (   64.40 ms per token,    15.53 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    1485.23 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7055.07 ms /   108 tokens (   65.32 ms per token,    15.31 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7076.79 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7746.04 ms /   120 tokens (   64.55 ms per token,    15.49 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7769.01 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6676.15 ms /   103 tokens (   64.82 ms per token,    15.43 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6696.76 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5572.98 ms /    86 tokens (   64.80 ms per token,    15.43 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5589.65 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5017.60 ms /    77 tokens (   65.16 ms per token,    15.35 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5032.77 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6467.47 ms /    98 tokens (   65.99 ms per token,    15.15 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6487.95 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6115.40 ms /    94 tokens (   65.06 ms per token,    15.37 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6134.55 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4885.00 ms /    74 tokens (   66.01 ms per token,    15.15 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4900.56 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5900.85 ms /    90 tokens (   65.56 ms per token,    15.25 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5919.21 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4349.40 ms /    66 tokens (   65.90 ms per token,    15.17 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4362.98 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5111.73 ms /    78 tokens (   65.54 ms per token,    15.26 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5127.83 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5670.79 ms /    87 tokens (   65.18 ms per token,    15.34 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5688.56 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5015.29 ms /    77 tokens (   65.13 ms per token,    15.35 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5031.35 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5683.60 ms /    88 tokens (   64.59 ms per token,    15.48 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5700.55 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6035.02 ms /    93 tokens (   64.89 ms per token,    15.41 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6054.03 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5077.96 ms /    78 tokens (   65.10 ms per token,    15.36 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5093.27 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5518.42 ms /    85 tokens (   64.92 ms per token,    15.40 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5535.84 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5441.29 ms /    82 tokens (   66.36 ms per token,    15.07 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5458.78 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5355.18 ms /    82 tokens (   65.31 ms per token,    15.31 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5372.43 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5065.60 ms /    78 tokens (   64.94 ms per token,    15.40 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5081.15 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4557.16 ms /    70 tokens (   65.10 ms per token,    15.36 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4571.19 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    2793.46 ms /    43 tokens (   64.96 ms per token,    15.39 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    2803.20 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6452.93 ms /    98 tokens (   65.85 ms per token,    15.19 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6473.65 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4935.28 ms /    75 tokens (   65.80 ms per token,    15.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4950.60 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6980.43 ms /   107 tokens (   65.24 ms per token,    15.33 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7001.86 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5689.94 ms /    88 tokens (   64.66 ms per token,    15.47 tokens per second)
# llama_print_timings:        eval time =     142.13 ms /     1 runs   (  142.13 ms per token,     7.04 tokens per second)
# llama_print_timings:       total time =    5850.99 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4708.64 ms /    72 tokens (   65.40 ms per token,    15.29 tokens per second)
# llama_print_timings:        eval time =     142.03 ms /     1 runs   (  142.03 ms per token,     7.04 tokens per second)
# llama_print_timings:       total time =    4866.60 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5192.44 ms /    80 tokens (   64.91 ms per token,    15.41 tokens per second)
# llama_print_timings:        eval time =     141.43 ms /     1 runs   (  141.43 ms per token,     7.07 tokens per second)
# llama_print_timings:       total time =    5350.59 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5154.18 ms /    79 tokens (   65.24 ms per token,    15.33 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5169.78 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4676.61 ms /    72 tokens (   64.95 ms per token,    15.40 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4690.81 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5140.16 ms /    79 tokens (   65.07 ms per token,    15.37 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5155.51 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6028.80 ms /    92 tokens (   65.53 ms per token,    15.26 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6047.05 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4557.31 ms /    70 tokens (   65.10 ms per token,    15.36 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4571.03 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4948.98 ms /    76 tokens (   65.12 ms per token,    15.36 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4964.06 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6710.82 ms /   103 tokens (   65.15 ms per token,    15.35 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6730.90 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4335.83 ms /    66 tokens (   65.69 ms per token,    15.22 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4349.93 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3881.18 ms /    59 tokens (   65.78 ms per token,    15.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3893.44 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3355.50 ms /    51 tokens (   65.79 ms per token,    15.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3366.08 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5567.05 ms /    86 tokens (   64.73 ms per token,    15.45 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5583.97 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5010.26 ms /    77 tokens (   65.07 ms per token,    15.37 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5026.10 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5116.11 ms /    78 tokens (   65.59 ms per token,    15.25 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5131.50 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5376.81 ms /    82 tokens (   65.57 ms per token,    15.25 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5394.01 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6773.99 ms /   104 tokens (   65.13 ms per token,    15.35 tokens per second)
# llama_print_timings:        eval time =     144.63 ms /     1 runs   (  144.63 ms per token,     6.91 tokens per second)
# llama_print_timings:       total time =    6940.34 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5622.64 ms /    87 tokens (   64.63 ms per token,    15.47 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5639.15 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5922.35 ms /    90 tokens (   65.80 ms per token,    15.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5940.79 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4696.17 ms /    72 tokens (   65.22 ms per token,    15.33 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4709.99 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5979.65 ms /    92 tokens (   65.00 ms per token,    15.39 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5998.15 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6248.48 ms /    96 tokens (   65.09 ms per token,    15.36 tokens per second)
# llama_print_timings:        eval time =     143.79 ms /     1 runs   (  143.79 ms per token,     6.95 tokens per second)
# llama_print_timings:       total time =    6412.89 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5202.07 ms /    77 tokens (   67.56 ms per token,    14.80 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5217.65 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6023.36 ms /    92 tokens (   65.47 ms per token,    15.27 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6042.34 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4687.94 ms /    72 tokens (   65.11 ms per token,    15.36 tokens per second)
# llama_print_timings:        eval time =     141.63 ms /     1 runs   (  141.63 ms per token,     7.06 tokens per second)
# llama_print_timings:       total time =    4844.62 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4108.09 ms /    63 tokens (   65.21 ms per token,    15.34 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4120.76 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5698.27 ms /    88 tokens (   64.75 ms per token,    15.44 tokens per second)
# llama_print_timings:        eval time =     160.24 ms /     1 runs   (  160.24 ms per token,     6.24 tokens per second)
# llama_print_timings:       total time =    5877.43 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5649.95 ms /    86 tokens (   65.70 ms per token,    15.22 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5667.52 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6170.28 ms /    94 tokens (   65.64 ms per token,    15.23 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6188.63 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4633.29 ms /    71 tokens (   65.26 ms per token,    15.32 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4647.03 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4703.39 ms /    72 tokens (   65.32 ms per token,    15.31 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4717.13 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5572.76 ms /    86 tokens (   64.80 ms per token,    15.43 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5590.12 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5176.93 ms /    80 tokens (   64.71 ms per token,    15.45 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5192.65 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7202.86 ms /   111 tokens (   64.89 ms per token,    15.41 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7224.52 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5681.66 ms /    88 tokens (   64.56 ms per token,    15.49 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5703.18 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5688.50 ms /    88 tokens (   64.64 ms per token,    15.47 tokens per second)
# llama_print_timings:        eval time =     141.41 ms /     1 runs   (  141.41 ms per token,     7.07 tokens per second)
# llama_print_timings:       total time =    5848.21 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5687.75 ms /    88 tokens (   64.63 ms per token,    15.47 tokens per second)
# llama_print_timings:        eval time =     141.74 ms /     1 runs   (  141.74 ms per token,     7.06 tokens per second)
# llama_print_timings:       total time =    5848.07 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6679.81 ms /   102 tokens (   65.49 ms per token,    15.27 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6700.34 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6954.41 ms /   106 tokens (   65.61 ms per token,    15.24 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6975.62 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4692.44 ms /    72 tokens (   65.17 ms per token,    15.34 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4706.79 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5166.68 ms /    80 tokens (   64.58 ms per token,    15.48 tokens per second)
# llama_print_timings:        eval time =     142.13 ms /     1 runs   (  142.13 ms per token,     7.04 tokens per second)
# llama_print_timings:       total time =    5325.71 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4701.65 ms /    72 tokens (   65.30 ms per token,    15.31 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4715.01 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5813.22 ms /    88 tokens (   66.06 ms per token,    15.14 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5829.78 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5537.40 ms /    85 tokens (   65.15 ms per token,    15.35 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5554.93 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5354.09 ms /    82 tokens (   65.29 ms per token,    15.32 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5370.63 ms
#
# ...
# llama_print_timings: prompt eval time =    8260.36 ms /   128 tokens (   64.53 ms per token,    15.50 tokens per second)
# llama_print_timings:        eval time =     143.65 ms /     1 runs   (  143.65 ms per token,     6.96 tokens per second)
# llama_print_timings:       total time =    8430.12 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =   10094.97 ms /   154 tokens (   65.55 ms per token,    15.26 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =   10126.15 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    9084.08 ms /   139 tokens (   65.35 ms per token,    15.30 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    9112.40 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    9733.00 ms /   149 tokens (   65.32 ms per token,    15.31 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    9762.61 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7569.23 ms /   115 tokens (   65.82 ms per token,    15.19 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7593.66 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    8112.93 ms /   124 tokens (   65.43 ms per token,    15.28 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    8137.74 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    8600.88 ms /   132 tokens (   65.16 ms per token,    15.35 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    8627.41 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    9037.95 ms /   138 tokens (   65.49 ms per token,    15.27 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    9065.59 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    8777.94 ms /   135 tokens (   65.02 ms per token,    15.38 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    8804.20 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6192.22 ms /    96 tokens (   64.50 ms per token,    15.50 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6211.03 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6558.36 ms /   100 tokens (   65.58 ms per token,    15.25 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6578.50 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    8261.86 ms /   128 tokens (   64.55 ms per token,    15.49 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    8286.15 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5002.11 ms /    77 tokens (   64.96 ms per token,    15.39 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5017.80 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5527.43 ms /    85 tokens (   65.03 ms per token,    15.38 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5544.21 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    8812.28 ms /   134 tokens (   65.76 ms per token,    15.21 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    8838.92 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5517.24 ms /    85 tokens (   64.91 ms per token,    15.41 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5534.50 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7059.17 ms /   108 tokens (   65.36 ms per token,    15.30 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7080.51 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5725.26 ms /    88 tokens (   65.06 ms per token,    15.37 tokens per second)
# llama_print_timings:        eval time =     141.76 ms /     1 runs   (  141.76 ms per token,     7.05 tokens per second)
# llama_print_timings:       total time =    5885.83 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5919.70 ms /    90 tokens (   65.77 ms per token,    15.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    5938.58 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6716.00 ms /   104 tokens (   64.58 ms per token,    15.49 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6736.59 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7212.68 ms /   111 tokens (   64.98 ms per token,    15.39 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7234.66 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    4092.60 ms /    63 tokens (   64.96 ms per token,    15.39 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    4104.66 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6027.96 ms /    93 tokens (   64.82 ms per token,    15.43 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6046.84 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    3300.07 ms /    50 tokens (   66.00 ms per token,    15.15 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    3310.56 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    5186.32 ms /    80 tokens (   64.83 ms per token,    15.43 tokens per second)
# llama_print_timings:        eval time =     142.11 ms /     1 runs   (  142.11 ms per token,     7.04 tokens per second)
# llama_print_timings:       total time =    5344.90 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7519.86 ms /   116 tokens (   64.83 ms per token,    15.43 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7542.77 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7057.59 ms /   107 tokens (   65.96 ms per token,    15.16 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7078.98 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    6225.41 ms /    96 tokens (   64.85 ms per token,    15.42 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    6244.89 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    7230.78 ms /   112 tokens (   64.56 ms per token,    15.49 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    7252.28 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =   10295.43 ms /   158 tokens (   65.16 ms per token,    15.35 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =   10325.89 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    9960.54 ms /   152 tokens (   65.53 ms per token,    15.26 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    9989.77 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =   10053.99 ms /   154 tokens (   65.29 ms per token,    15.32 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =   10084.86 ms
#
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =   10003.64 ms /   152 tokens (   65.81 ms per token,    15.19 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =   10032.90 ms
# ##########################
# ### Store in database  ###
# ##########################
# llama_print_timings:        load time =     515.20 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =    8618.69 ms /   131 tokens (   65.79 ms per token,    15.20 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =    8645.13 ms

# %%
from langchain.llms.llamacpp import LlamaCpp
from langchain_community.vectorstores.chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

database_path = "/home/tpllmws23/Chatbot-LLama-Pruefungsamt/Chatbot-Jan/chromadb_lanchain_rag_auto_embeddings/"
database_collection = "Pruefungsamt"
model_path = "/home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf"

n_ctx = 4096

callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

llm = LlamaCpp(model_path=model_path,
        n_gpu_layers=-1,
        n_batch=512,
        n_ctx=n_ctx,
        f16_kv=True,
        verbose=False,
        temperature=0.0,
        top_p=1,
        callback_manager=callback_manager,
        return_full_text=False
)

from langchain_community.embeddings import LlamaCppEmbeddings
embedding = LlamaCppEmbeddings(model_path=model_path,
        n_gpu_layers=-1,
        n_batch=512,
        n_ctx=n_ctx,
        f16_kv=True
        )

db = Chroma(
    persist_directory=database_path, 
    collection_name=database_collection, 
    embedding_function=embedding
)
retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": 10})
# Out:
# /home/tpllmws23/.pyenv/versions/3.11.7/lib/python3.11/site-packages/langchain_core/utils/utils.py:159: UserWarning: WARNING! return_full_text is not default parameter.
#                 return_full_text was transferred to model_kwargs.
#                 Please confirm that return_full_text is what you intended.
#   warnings.warn(
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: NVIDIA TITAN RTX, compute capability 7.5, VMM: yes
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V2
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: n_embd_k_gqa     = 5120
# llm_load_print_meta: n_embd_v_gqa     = 5120
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 7.33 GiB (4.83 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size       =    0.14 MiB
# llm_load_tensors: using CUDA for GPU acceleration
# llm_load_tensors: system memory used  =   88.03 MiB
# llm_load_tensors: VRAM used           = 7412.96 MiB
# llm_load_tensors: offloading 40 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 41/41 layers to GPU
# ....................................................................................................
# llama_new_context_with_model: n_ctx      = 4096
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  = 3200.00 MiB, K (f16): 1600.00 MiB, V (f16): 1600.00 MiB
# llama_build_graph: non-view tensors processed: 844/844
# llama_new_context_with_model: compute buffer total size = 361.19 MiB
# llama_new_context_with_model: VRAM scratch buffer: 358.00 MiB
# llama_new_context_with_model: total VRAM used: 7770.96 MiB (model: 7412.96 MiB, context: 358.00 MiB)
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V2
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: n_embd_k_gqa     = 5120
# llm_load_print_meta: n_embd_v_gqa     = 5120
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 7.33 GiB (4.83 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size       =    0.14 MiB
# llm_load_tensors: using CUDA for GPU acceleration
# llm_load_tensors: system memory used  =   88.03 MiB
# llm_load_tensors: VRAM used           = 7412.96 MiB
# llm_load_tensors: offloading 40 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 41/41 layers to GPU
# ....................................................................................................
# llama_new_context_with_model: n_ctx      = 4096
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  = 3200.00 MiB, K (f16): 1600.00 MiB, V (f16): 1600.00 MiB
# llama_build_graph: non-view tensors processed: 844/844
# llama_new_context_with_model: compute buffer total size = 361.19 MiB
# llama_new_context_with_model: VRAM scratch buffer: 358.00 MiB
# llama_new_context_with_model: total VRAM used: 7770.96 MiB (model: 7412.96 MiB, context: 358.00 MiB)
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 1 | AVX512_VBMI = 0 | AVX512_VNNI = 1 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %%
db.similarity_search("What are the requirements for studying MSI in masters degree at the HTWG?", k=8)
# Out:
# llama_print_timings:        load time =      85.62 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =     373.31 ms /    19 tokens (   19.65 ms per token,    50.90 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =     375.62 ms
# [Document(page_content='•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)', metadata={'creation_date': '2023-11-20', 'file_name': 'Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf', 'file_size': 212749, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '12'}),
#  Document(page_content='▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )', metadata={'creation_date': '2023-11-20', 'file_name': 'Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf', 'file_size': 212749, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '14'}),
#  Document(page_content='-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.', metadata={'creation_date': '2023-11-20', 'file_name': 'Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_size': 656530, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '14'}),
#  Document(page_content='Prof. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.', metadata={'creation_date': '2023-11-20', 'file_name': 'Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_size': 656530, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '37'}),
#  Document(page_content='Prof. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.', metadata={'creation_date': '2023-11-20', 'file_name': 'Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_size': 656530, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '46'}),
#  Document(page_content='x AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)', metadata={'creation_date': '2023-11-20', 'file_name': 'Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf', 'file_size': 270726, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '1'}),
#  Document(page_content='-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.', metadata={'creation_date': '2023-11-20', 'file_name': 'Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_size': 656530, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '28'}),
#  Document(page_content='Seminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)', metadata={'creation_date': '2023-11-20', 'file_name': 'Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf', 'file_size': 270726, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '1'})]

# %%
from operator import itemgetter
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain.chains import LLMChain
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain.chains import create_retrieval_chain
from langchain.globals import set_debug
from langchain.chains.combine_documents import create_stuff_documents_chain


retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": 10})
set_debug(True)

template = """Answer the following question based only on the provided context:
{context}

Question: {input}"""

prompt = ChatPromptTemplate.from_template(template)

document_chain = create_stuff_documents_chain(llm, prompt)
retrieval_chain = create_retrieval_chain(retriever, document_chain)

chain = (
    {"context": retriever, "input": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
response = retrieval_chain.invoke({"input": "What are the requirements for studying MSI in masters degree at the HTWG?"})
# Out:
# [chain/start] [1:chain:retrieval_chain] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/start] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context>] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/start] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context> > 3:chain:RunnableParallel<context>] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/start] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context> > 3:chain:RunnableParallel<context> > 4:chain:retrieve_documents] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/start] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context> > 3:chain:RunnableParallel<context> > 4:chain:retrieve_documents > 5:chain:<lambda>] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/end] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context> > 3:chain:RunnableParallel<context> > 4:chain:retrieve_documents > 5:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# llama_print_timings:        load time =      85.62 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =     355.08 ms /    19 tokens (   18.69 ms per token,    53.51 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =     356.49 ms
# [chain/end] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context> > 3:chain:RunnableParallel<context> > 4:chain:retrieve_documents] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context> > 3:chain:RunnableParallel<context>] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [1:chain:retrieval_chain > 2:chain:RunnableAssign<context>] s] Exiting Chain run with output:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?",
#   "context": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_size": 212749,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "12"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_size": 212749,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "14"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "14"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Prof. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "37"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Prof. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "46"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "x AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_size": 270726,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "1"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "28"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Seminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_size": 270726,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "1"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": " Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "119_ZuSMa_Senat_18012022.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/119_ZuSMa_Senat_18012022.pdf",
#           "file_size": 355889,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "2"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "11"
#         }
#       }
#     }
#   ]
# }
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer>] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer>] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 10:chain:format_inputs] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 10:chain:format_inputs > 11:chain:RunnableParallel<context>] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 10:chain:format_inputs > 11:chain:RunnableParallel<context> > 12:chain:format_docs] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 10:chain:format_inputs > 11:chain:RunnableParallel<context> > 12:chain:format_docs] s] Exiting Chain run with output:
# {
#   "output": "•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)\n\n▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )\n\n-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nx AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)\n\n-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.\n\nSeminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)\n\n Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),\n\n-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018."
# }
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 10:chain:format_inputs > 11:chain:RunnableParallel<context>] s] Exiting Chain run with output:
# {
#   "context": "•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)\n\n▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )\n\n-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nx AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)\n\n-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.\n\nSeminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)\n\n Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),\n\n-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018."
# }
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 10:chain:format_inputs] s] Exiting Chain run with output:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?",
#   "context": "•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)\n\n▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )\n\n-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nx AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)\n\n-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.\n\nSeminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)\n\n Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),\n\n-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018."
# }
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 13:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?",
#   "context": "•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)\n\n▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )\n\n-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nx AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)\n\n-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.\n\nSeminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)\n\n Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),\n\n-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018."
# }
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 13:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "Answer the following question based only on the provided context:\n•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)\n\n▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )\n\n-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nx AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)\n\n-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.\n\nSeminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)\n\n Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),\n\n-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018.\n\nQuestion: What are the requirements for studying MSI in masters degree at the HTWG?",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 14:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Answer the following question based only on the provided context:\n•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)\n\n▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )\n\n-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nProf. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.\n\nx AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)\n\n-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.\n\nSeminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)\n\n Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),\n\n-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018.\n\nQuestion: What are the requirements for studying MSI in masters degree at the HTWG?"
#   ]
# }
#
#
# Please answer based on the provided context only.[llm/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 14:llm:LlamaCpp] [15.55s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "\n\nPlease answer based on the provided context only.",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 15:parser:StrOutputParser] Entering Parser run with input:
# {
#   "input": "\n\nPlease answer based on the provided context only."
# }
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain > 15:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "\n\nPlease answer based on the provided context only."
# }
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer> > 9:chain:stuff_documents_chain] [15.55s] Exiting Chain run with output:
# {
#   "output": "\n\nPlease answer based on the provided context only."
# }
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer> > 8:chain:RunnableParallel<answer>] [15.55s] Exiting Chain run with output:
# {
#   "answer": "\n\nPlease answer based on the provided context only."
# }
# [chain/end] [1:chain:retrieval_chain > 7:chain:RunnableAssign<answer>] [15.56s] Exiting Chain run with output:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?",
#   "context": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "•Cloud Application  Development (WS)\n•Concurrency  (SS) \n•Data Analysis (SS) \n•IT-Consulting (WS)\n•IT-Leadership: Entrepreneurship (SS) + IoT \n(SS)\n•Konzepte aktueller Datenbanksysteme (SS)\n•Mobile Kommunikation und Kollaboration (WS)\n•Quantum Computing (SS)\n•Reactive  Systems (WS)",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_size": 212749,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "12"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "▪Prüfungsausschussvorsitz \nProf. Dr. Alexander Hoffmann ( alexander.hoffmann@htwg -konstanz.de )\n▪Auslandssemester                                                                                     \nProf. Dr. Marco Mevius  (mmevius@htwg -konstanz.de )",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Infoveranstaltung_Masterstudiengaenge-Informatik_HTWG-Konstanz.pdf",
#           "file_size": 212749,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "14"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "-    Thrun, Burgard and Fox, Probabilistic Robotics, MIT Press, 2005.\n-    Siegwart and Nourbakhsh, Introduction to Autonomous Mobile Robots, 2nd ed. ,\nMIT Press, 2011.\n-    Choset et al., Principles of Robot Motion, MIT Press, 2005.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "14"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Prof. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "37"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Prof. Dr. H. LangwegÜ,\nLÜ1 2o\nLehrmaterial englisch. Individuelle Betreuung deutsch/englisch\nabhängig von Teilnahme von Austauschstudierende teilnehmen.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "46"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "x AS08 VASY Vernetzung autonomer Systeme X  X 2 1 3 5 SP (AB) \nAS01 AURO Autonome Roboter  X  X 2 1 3 5 M30, SP(LP)\nAS10 SE QC Quantum Computing  X  X 2 1 3 5 K90, SP(LP)\nAS04 GM Geometric Modeling  X  X 2 1 3 5 M30, SP(LP)\nAS02 CV Computer Vision    X 2 1 3 5 M30, SP(LP)",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_size": 270726,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "1"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "-    Marlon Dumas; Wil van der Aalst; Arthur ter Hofstede, Process-Aware Information\nSystems. Bridging People and Software through Process Technology, John Wiley\n& Sons, 2005.\n-    Mathias Weske: Business Process Management: Concepts, Languages,\nArchitectures Springer, 2007.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "28"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "Seminar: IoT and Environmental Sustainability ?  5 evtl. erst ab SS25\nSeminar: Mobile Roboter X X 5\n− Interaktive Anwendungssysteme in der Wissensgesellschaft X     4 5 SP (PR) \n− Complex Event Processing   ? 2 1 3 5 SP (AB, LP, PR)",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Wahlpflichtmodule_Master-Informatik_WS23_Stand_21-Sep-2023.pdf",
#           "file_size": 270726,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "1"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": " Automotive Systems Engineering (ASE),  \n Umwelt - und Verfahrenstechnik (UVT),  \n Wirtschaftsingenieurwesen (MWI),  \n Mechatronik (MME),  \n Industrial  Engineering and Management ( MIE), \n Unternehmensführung (BWM),  \n International  Management Asia- Europe (MIM),",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "119_ZuSMa_Senat_18012022.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/119_ZuSMa_Senat_18012022.pdf",
#           "file_size": 355889,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "2"
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "document",
#         "Document"
#       ],
#       "kwargs": {
#         "page_content": "-    Rosen: Discrete Mathematics and its Applications, McGraw-Hill, 7th edition,\n2012.\n-    Epp: Discrete Mathematics with Applications, Brooks/Cole, 4th edition, 2012.\n-    Homeister: Quantum Computing verstehen, Springer Vieweg, 5. Auflage, 2018.",
#         "metadata": {
#           "creation_date": "2023-11-20",
#           "file_name": "Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_path": "/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf",
#           "file_size": 656530,
#           "file_type": "application/pdf",
#           "last_accessed_date": "2024-02-14",
#           "last_modified_date": "2023-11-20",
#           "page_label": "11"
#         }
#       }
#     }
#   ],
#   "answer": "\n\nPlease answer based on the provided context only."
# }
# [chain/end] [1:chain:retrieval_chain] [15.94s] Exiting Chain run with output:
# [outputs]

# %%
for chunk in chain.invoke({"input": "What are the requirements for studying MSI in masters degree at the HTWG?"}):
    print(chunk, end="", flush=True)
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,input>] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,input> > 4:chain:RunnablePassthrough] Entering Chain run with input:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,input> > 4:chain:RunnablePassthrough] s] Exiting Chain run with output:
# {
#   "input": "What are the requirements for studying MSI in masters degree at the HTWG?"
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel<context,input>] s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "Answer the following question based only on the provided context:\n[Document(page_content='Punkte unbenotete \\nLeistungs-nachweise benotete Modul- \\nbzw. \\nModulteilprüfungen \\n1 Komplexitätstheorie   3   \\n - Komplexitätstheorie A 3  K90 \\n      \\n2 Algorithmentechnik  3   \\n - Algorithmentechnik  B 3  K90  \\n      \\n3 Diskrete Mathematik  3   \\n - Diskrete Mathematik  A 3  K90', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '7'}), Document(page_content='- Seminar  W  2 (2)  \\n        \\n6 Team-Projekt PM  2    \\n - Team-Projekt  P  1 1  \\n        \\n7 Wahlpflichtmodul IT-Management 1 2) WPM   3    \\n - Wahlpflichtmodul IT-Management 1  X  (3) 3  \\n        \\n8 Wahlpflichtmodul IT-Management 2 2) WPM   3    \\n - Wahlpflichtmodul IT-Management 2  X  (3) 3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '3'}), Document(page_content='- Team-Projekt  P  1 1  \\n        \\n7 Wahlpflichtmodul Autonome Systeme 1 2) WPM   3    \\n - Wahlpflichtmodul Autonome Systeme 1  X  (3) 3  \\n        \\n8 Wahlpflichtmodul Autonome Systeme 2 2) WPM   3    \\n - Wahlpflichtmodul Autonome Systeme 2  X  (3) 3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '2'}), Document(page_content='8 Wahlpflichtmodul Software Engineering 2 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 2  X  (3) 3  \\n        \\n9 Wahlpflichtmodul Software Engineering 3 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 3  X  (3) 3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '4'}), Document(page_content='- Seminar  W  2 (2)  \\n        \\n6 Team-Projekt PM  2    \\n - Team-Projekt  P  1 1  \\n        \\n7 Wahlpflichtmodul Software Engineering 1 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 1  X  (3) 3  \\n        \\n8 Wahlpflichtmodul Software Engineering 2 2) WPM   3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '4'}), Document(page_content='- Wahlpflichtmodul Software Engineering 3  X  (3) 3  \\n        \\n10 Wahlpflichtmodul Software Engineering 4 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 4  X  3 (3)  \\n        \\n11 Wahlpflichtmodul Software Engineering 5 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 5  X  3 (3)', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '4'}), Document(page_content='- Team-Projekt  8   \\n      \\n7 Wahlpflichtmodul Software Engineering 1 A/B 5   \\n - Wahl nach veröffentlichtem  MSI-WPM-Ka ...
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 6:llm:LlamaCpp] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Answer the following question based only on the provided context:\n[Document(page_content='Punkte unbenotete \\nLeistungs-nachweise benotete Modul- \\nbzw. \\nModulteilprüfungen \\n1 Komplexitätstheorie   3   \\n - Komplexitätstheorie A 3  K90 \\n      \\n2 Algorithmentechnik  3   \\n - Algorithmentechnik  B 3  K90  \\n      \\n3 Diskrete Mathematik  3   \\n - Diskrete Mathematik  A 3  K90', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '7'}), Document(page_content='- Seminar  W  2 (2)  \\n        \\n6 Team-Projekt PM  2    \\n - Team-Projekt  P  1 1  \\n        \\n7 Wahlpflichtmodul IT-Management 1 2) WPM   3    \\n - Wahlpflichtmodul IT-Management 1  X  (3) 3  \\n        \\n8 Wahlpflichtmodul IT-Management 2 2) WPM   3    \\n - Wahlpflichtmodul IT-Management 2  X  (3) 3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '3'}), Document(page_content='- Team-Projekt  P  1 1  \\n        \\n7 Wahlpflichtmodul Autonome Systeme 1 2) WPM   3    \\n - Wahlpflichtmodul Autonome Systeme 1  X  (3) 3  \\n        \\n8 Wahlpflichtmodul Autonome Systeme 2 2) WPM   3    \\n - Wahlpflichtmodul Autonome Systeme 2  X  (3) 3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '2'}), Document(page_content='8 Wahlpflichtmodul Software Engineering 2 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 2  X  (3) 3  \\n        \\n9 Wahlpflichtmodul Software Engineering 3 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 3  X  (3) 3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '4'}), Document(page_content='- Seminar  W  2 (2)  \\n        \\n6 Team-Projekt PM  2    \\n - Team-Projekt  P  1 1  \\n        \\n7 Wahlpflichtmodul Software Engineering 1 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 1  X  (3) 3  \\n        \\n8 Wahlpflichtmodul Software Engineering 2 2) WPM   3', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '4'}), Document(page_content='- Wahlpflichtmodul Software Engineering 3  X  (3) 3  \\n        \\n10 Wahlpflichtmodul Software Engineering 4 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 4  X  3 (3)  \\n        \\n11 Wahlpflichtmodul Software Engineering 5 2) WPM   3    \\n - Wahlpflichtmodul Software Engineering 5  X  3 (3)', metadata={'creation_date': '2023-11-20', 'file_name': 'SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_path': '/home/tpllmws23/llms/main_data/SPO_MSI_SPONr5_Senat_10122019.pdf', 'file_size': 170767, 'file_type': 'application/pdf', 'last_accessed_date': '2024-02-14', 'last_modified_date': '2023-11-20', 'page_label': '4'}), Document(page_content='- Team-Projekt  8   \\n      \\n7 Wahlpflichtmodul Software Engineering 1 A/B 5   \\n - Wahl nach veröffentlichtem  MSI-WPM-Katalog, s.  ...
#   ]
# }
# llama_print_timings:        load time =      85.62 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =      79.61 ms /     2 tokens (   39.80 ms per token,    25.12 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =      83.67 ms
# Please provide the answer based on the given context.[llm/end] [1:chain:RunnableSequence > 6:llm:LlamaCpp] [4.93s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "\n\nPlease provide the answer based on the given context.",
#         "generation_info": null,
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 7:parser:StrOutputParser] Entering Parser run with input:
# {
#   "input": "\n\nPlease provide the answer based on the given context."
# }
# [chain/end] [1:chain:RunnableSequence > 7:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "\n\nPlease provide the answer based on the given context."
# }
# [chain/end] [1:chain:RunnableSequence] [5.04s] Exiting Chain run with output:
# {
#   "output": "\n\nPlease provide the answer based on the given context."
# }
#
#
# Please provide the answer based on the given context.

# %% [markdown]
# Hier wird die Datenbank in langchain eingebunden

# %%
model_path = "/home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf"
database_path = "/home/tpllmws23/Chatbot-LLama-Pruefungsamt/Chatbot-Jan/chromadb"
collection_name = "Pruefungsamt"
n_ctx = 8192

from langchain_core.prompts import ChatPromptTemplate
from langchain.llms.llamacpp import LlamaCpp
from langchain_community.vectorstores.chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
import chromadb

llm = LlamaCpp(model_path=model_path,
        n_gpu_layers=-1,
        n_batch=512,
        n_ctx=n_ctx,
        f16_kv=True,
        verbose=False,
        temperature=0.0,
)

from langchain_community.embeddings import LlamaCppEmbeddings
embedding = LlamaCppEmbeddings(model_path=model_path,
        n_gpu_layers=-1,
        n_batch=512,
        n_ctx=n_ctx,
        f16_kv=True
        )

db = Chroma(
    persist_directory=database_path, 
    collection_name=collection_name, 
    embedding_function=embedding
)
retriever = db.as_retriever()
# Out:
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   no
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: yes
# ggml_init_cublas: found 1 CUDA devices:
#   Device 0: NVIDIA TITAN RTX, compute capability 7.5, VMM: yes
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V2
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: n_embd_k_gqa     = 5120
# llm_load_print_meta: n_embd_v_gqa     = 5120
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 7.33 GiB (4.83 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size       =    0.14 MiB
# llm_load_tensors: using CUDA for GPU acceleration
# llm_load_tensors: system memory used  =   88.03 MiB
# llm_load_tensors: VRAM used           = 7412.96 MiB
# llm_load_tensors: offloading 40 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 41/41 layers to GPU
# ....................................................................................................
# llama_new_context_with_model: n_ctx      = 8192
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  = 6400.00 MiB, K (f16): 3200.00 MiB, V (f16): 3200.00 MiB
# llama_build_graph: non-view tensors processed: 844/844
# llama_new_context_with_model: compute buffer total size = 689.19 MiB
# llama_new_context_with_model: VRAM scratch buffer: 686.00 MiB
# llama_new_context_with_model: total VRAM used: 8098.96 MiB (model: 7412.96 MiB, context: 686.00 MiB)
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /home/tpllmws23/llms/llama-2-13b-chat.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V2
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: n_embd_k_gqa     = 5120
# llm_load_print_meta: n_embd_v_gqa     = 5120
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 7.33 GiB (4.83 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size       =    0.14 MiB
# llm_load_tensors: using CUDA for GPU acceleration
# llm_load_tensors: system memory used  =   88.03 MiB
# llm_load_tensors: VRAM used           = 7412.96 MiB
# llm_load_tensors: offloading 40 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 41/41 layers to GPU
# ....................................................................................................
# llama_new_context_with_model: n_ctx      = 8192
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  = 6400.00 MiB, K (f16): 3200.00 MiB, V (f16): 3200.00 MiB
# llama_build_graph: non-view tensors processed: 844/844
# llama_new_context_with_model: compute buffer total size = 689.19 MiB
# llama_new_context_with_model: VRAM scratch buffer: 686.00 MiB
# llama_new_context_with_model: total VRAM used: 8098.96 MiB (model: 7412.96 MiB, context: 686.00 MiB)
# AVX = 1 | AVX_VNNI = 0 | AVX2 = 1 | AVX512 = 1 | AVX512_VBMI = 0 | AVX512_VNNI = 1 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# Einfache Chain

# %%
from operator import itemgetter

template = """You are a chatbot and answer questions. Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

chain = (
    {
        "context": itemgetter("question") | retriever,
        "question": itemgetter("question"),
    }
    | prompt
    
    | llm
    | StrOutputParser()
)

response = chain.invoke({"question": "What are the requirements for studying MSI in masters degree at the HTWG?"})
print(response)
# Out:
# llama_print_timings:        load time =     317.06 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =     312.03 ms /    19 tokens (   16.42 ms per token,    60.89 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =     314.53 ms
# oder oder.']
#
#
#
# oder oder oder oder, oder oder
#
#
#
#
#
#
#
#
# the
#
#
#
#
#
#
#
# 6,4, 3, and.].
#
#
#
# oder oder.']
#
#
#
# oder oder oder oder, oder oder
#
#
#
#
#
#
#
#
# the
#
#
#
#
#
#
#
# 6,4, 3, and.].

# %%
from operator import itemgetter

from langchain.memory import ConversationBufferMemory

from langchain.schema import format_document
from langchain_core.messages import AIMessage, HumanMessage, get_buffer_string
from langchain_core.runnables import RunnableParallel

from langchain.prompts.prompt import PromptTemplate

_template = """Given the following conversation and a follow up question, rephrase the follow up question to be a standalone question, in its original language.

Chat History:
{chat_history}
Follow Up Input: {question}
Standalone question:"""
CONDENSE_QUESTION_PROMPT = PromptTemplate.from_template(_template)

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
ANSWER_PROMPT = ChatPromptTemplate.from_template(template)

DEFAULT_DOCUMENT_PROMPT = PromptTemplate.from_template(template="{page_content}")


def _combine_documents(
    docs, document_prompt=DEFAULT_DOCUMENT_PROMPT, document_separator="\n\n"
):
    doc_strings = [format_document(doc, document_prompt) for doc in docs]
    return document_separator.join(doc_strings)

_inputs = RunnableParallel(
    standalone_question=RunnablePassthrough.assign(
        chat_history=lambda x: get_buffer_string(x["chat_history"])
    )
    | CONDENSE_QUESTION_PROMPT
    | llm
    | StrOutputParser(),
)
_context = {
    "context": itemgetter("standalone_question") | retriever | _combine_documents,
    "question": lambda x: x["standalone_question"],
}
conversational_qa_chain = _inputs | _context | ANSWER_PROMPT | llm

memory = ConversationBufferMemory(
    return_messages=True, output_key="answer", input_key="question"
)

# First we add a step to load memory
# This adds a "memory" key to the input object
loaded_memory = RunnablePassthrough.assign(
    chat_history=RunnableLambda(memory.load_memory_variables) | itemgetter("history"),
)
# Now we calculate the standalone question
standalone_question = {
    "standalone_question": {
        "question": lambda x: x["question"],
        "chat_history": lambda x: get_buffer_string(x["chat_history"]),
    }
    | CONDENSE_QUESTION_PROMPT
    | llm
    | StrOutputParser(),
}
# Now we retrieve the documents
retrieved_documents = {
    "docs": itemgetter("standalone_question") | retriever,
    "question": lambda x: x["standalone_question"],
}
# Now we construct the inputs for the final prompt
final_inputs = {
    "context": lambda x: _combine_documents(x["docs"]),
    "question": itemgetter("question"),
}
# And finally, we do the part that returns the answers
answer = {
    "answer": final_inputs | ANSWER_PROMPT | llm,
    "docs": itemgetter("docs"),
}
# And now we put it all together!
final_chain = loaded_memory | standalone_question | retrieved_documents | answer

inputs = {"question": "What are the requirements for studying MSI in masters degree at the HTWG?"}
result = final_chain.invoke(inputs)
print(result)

# For now you need to save it yourself
memory.save_context(inputs, {"answer": result["answer"].content})
memory.load_memory_variables({})

inputs = {"question": "Are there special requirements for 'Autonome Systeme'?"}
result = final_chain.invoke(inputs)
print(result)
# Out:
# llama_print_timings:        load time =     632.07 ms
# llama_print_timings:      sample time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings: prompt eval time =     630.89 ms /    58 tokens (   10.88 ms per token,    91.93 tokens per second)
# llama_print_timings:        eval time =       0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =     633.23 ms
# {'answer': '\nI have attached the module handbook and the course catalog for your reference. Please let me know if there are any specific requirements or prerequisites that I need to fulfill before applying for the program.\n\nThank you for your time and assistance.', 'docs': [Document(page_content='Hochschule Konstanz Modulhandbuch des Studiengangs\nFakultät InformatikPlaceholder Informatik, Master of Science\nModul ITM06 Strategic IT-Management 1 (Building the IT-Leadership System)\nModul-Koordination Start Modul-Kürzel/-Nr. ECTS-Punkte Arbeitsaufwand\nProf. Dr. C. Rentrop SS SIM1/ITM06 5 150 h\n Dauer SWS Kontaktzeit Selbststudium\n 1 Semester 3 45 h 105 h\nEinsatz des Moduls im\nStudiengangAngestrebter\nAbschlussModul-Typ\n(PM/WPM)Beginn im\nStudiensemesterSPO-Version /\nJahr\nMSI M.Sc. WPM A/B SPO 5 / 2020\nInhaltliche Teilnahme\nVoraussetzung\nVerwendbarkeit des Moduls\nim o.g. StudiengangAls Vorkenntnis erforderlich für Modul:\nSinnvoll zu kombinieren mit Modul:\nPüfungsleistungen\ndes ModulsBenotete PrüfungUnbenotete\nPrüfungUnbenoteter\nLeistungsnachweis\nModulprüfung (MP) SP (LP, PR, AB, PJ) \nModulteilprüfung (MTP) \nZusammensetzung\nder Endnote S Note der benoteten Modul(teil)prüfung\n £ ECTS-gewichtetes, arithmetisches Mittel der benoteten Modulteilprüfungen\n £ Sonstiges:\nLernziele des\nModuls\nFachliche Kompetenzen\nIn Industrieunternehmen hat die IT inzwischen eine sehr hohe Bedeutung gewonnen. Insofern ist die IT\nselbst und damit auch die strategische Steuerung der IT ein Erfolgsfaktor für die Unternehmen\ngeworden. Im Rahmen dieses Moduls lernen die Studierenden die Aufgaben und Funktionsweisen des\nFührungssystems der IT kennen. Anhand von Praxisvorträgen und kleinen Fallstudien und Workshops\nwerden diese auch an Beispielfällen angewendet und damit der Transfer in die Praxis geübt.\nIT has gained a strategic role for many companies and thus become a crtitical success factor for\nbusiness organisations. In this module students will learn about the leadership system for IT. In case\nstudies and workshops the participants will apply theory on practical problems.\nPersonale Kompetenzen\nDas Modul vermittelt IT-spezifische rechtliche und betriebswirtschaftliche Fachkenntnisse, die bei der\nFührung eines IT-Bereiches zum Einsatz angewendet werden können.\nLehr- und Lernformen  S Vorlesung  £ Übung  S Selbststudium  S Workshop/Seminar  S Projekt  £ Labor\n£ Exkursion  £ E-Learning  £ Hausarbeit  £ Intensivsprachkurs  £ Sonstiges:\nTeilmodul\nLehrendeArt SWS ECTS Lehrinhalt\nStrategic IT-Management\nProf. Dr. C. RentropV 3 5o\n-    IT-Leadership System\no    Definition and Elements\no    Link to IT-Strategy\n-    Developing the IT-Governance\no    IT-Governance definition\no    Symptoms of poor Governance\no    Elements and guidelines for an IT-Governance\no    How to use frameworks\n-    Financial Management & KPI\no    Calculation and Allocation of IT Cost\no    Developing an KPI set for IT\nLiteratur/Medien\n-    Gadatsch, Andreas; Mayer, Elmar: Masterkurs IT-Controlling, 5. Aufl., München,\nSpringer, 2014.\n-    Buchta, Dirk et al.: Strategisches IT-Management, 3. Aufl., Wiesbaden, Gabler,\n2009.\n-    Abolhassan, Ferri: The road to a modern IT factory, Heidelberg, Springer, 2014.', metadata={'creation_date': '2023-11-20', 'file_name': 'Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_path': '/home/tpllmws23/llms/main_data/Modulhandbuch_MSI_SS23_Stand_10-Jan-2023.pdf', 'file_size': 656530, 'file_type': 'application/pdf', 'last_accessed_date': '2024-01-16', 'last_modified_date': '2023-11-20', 'page_label': '33'}), Document(page_content='Hochschule Konstanz Modulhandbuch des Studiengangs\nFakultät InformatikPlaceholder Informatik, Master of Science\nModul ITM06 Strategic IT-Management 1 (Building the IT-Leadership System)\nModul-Koordination Start Modul-Kürzel/-Nr. ECTS-Punkte Arbeitsaufwand\nProf. Dr. C. Rentrop SS SIM1/ITM06 5 150 h\n Dauer SWS Kontaktzeit Selbststudium\n 1 Semester 3 45 h 105 h\nEinsatz  ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 91
#      88 print(result)
#      90 # For now you need to save it yourself
# ---> 91 memory.save_context(inputs, {"answer": result["answer"].content})
#      92 memory.load_memory_variables({})
#      94 inputs = {"question": "Are there special requirements for 'Autonome Systeme'?"}
#
# AttributeError: 'str' object has no attribute 'content'
